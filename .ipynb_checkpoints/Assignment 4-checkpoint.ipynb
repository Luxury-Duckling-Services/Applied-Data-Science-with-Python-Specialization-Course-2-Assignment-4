# %% [markdown]
# # UEFA Champion League Group Stages Accumulated Data From 1992-1993 Season To 2022-2023 Season

# %% [markdown]
# We scrape information of all group stages of UEFA Champion League, from 1992-1993 season to 2022-2023 season, from Wikipedia pages.
#
# From example, one can find all information regarding 1992-1993 season from:
# https://en.wikipedia.org/wiki/1992–93_UEFA_Champions_League.

# %%
url_prefix = "https://en.wikipedia.org/wiki/"
url_suffix = "_UEFA_Champions_League"

years_range = range(1992 , 2022)

url_array = []

for year in years_range:
    url_array.append(url_prefix + str(year) + "%E2%80%93" + str(year+1)[2:] + url_suffix)

url_array
# Out:
# ['https://en.wikipedia.org/wiki/1992%E2%80%9393_UEFA_Champions_League',
#  'https://en.wikipedia.org/wiki/1993%E2%80%9394_UEFA_Champions_League',
#  'https://en.wikipedia.org/wiki/1994%E2%80%9395_UEFA_Champions_League',
#  'https://en.wikipedia.org/wiki/1995%E2%80%9396_UEFA_Champions_League',
#  'https://en.wikipedia.org/wiki/1996%E2%80%9397_UEFA_Champions_League',
#  'https://en.wikipedia.org/wiki/1997%E2%80%9398_UEFA_Champions_League',
#  'https://en.wikipedia.org/wiki/1998%E2%80%9399_UEFA_Champions_League',
#  'https://en.wikipedia.org/wiki/1999%E2%80%9300_UEFA_Champions_League',
#  'https://en.wikipedia.org/wiki/2000%E2%80%9301_UEFA_Champions_League',
#  'https://en.wikipedia.org/wiki/2001%E2%80%9302_UEFA_Champions_League',
#  'https://en.wikipedia.org/wiki/2002%E2%80%9303_UEFA_Champions_League',
#  'https://en.wikipedia.org/wiki/2003%E2%80%9304_UEFA_Champions_League',
#  'https://en.wikipedia.org/wiki/2004%E2%80%9305_UEFA_Champions_League',
#  'https://en.wikipedia.org/wiki/2005%E2%80%9306_UEFA_Champions_League',
#  'https://en.wikipedia.org/wiki/2006%E2%80%9307_UEFA_Champions_League',
#  'https://en.wikipedia.org/wiki/2007%E2%80%9308_UEFA_Champions_League',
#  'https://en.wikipedia.org/wiki/2008%E2%80%9309_UEFA_Champions_League',
#  'https://en.wikipedia.org/wiki/2009%E2%80%9310_UEFA_Champions_League',
#  'https://en.wikipedia.org/wiki/2010%E2%80%9311_UEFA_Champions_League',
#  'https://en.wikipedia.org/wiki/2011%E2%80%9312_UEFA_Champions_League',
#  'https://en.wikipedia.org/wiki/2012%E2%80%9313_UEFA_Champions_League',
#  'https://en.wikipedia.org/wiki/2013%E2%80%9314_UEFA_Champions_League',
#  'https://en.wikipedia.org/wiki/2014%E2%80%9315_UEFA_Champions_League',
#  'https://en.wikipedia.org/wiki/2015%E2%80%9316_UEFA_Champions_League',
#  'https://en.wikipedia.org/wiki/2016%E2%80%9317_UEFA_Champions_League',
#  'https://en.wikipedia.org/wiki/2017%E2%80%9318_UEFA_Champions_League',
#  'https://en.wikipedia.org/wiki/2018%E2%80%9319_UEFA_Champions_League',
#  'https://en.wikipedia.org/wiki/2019%E2%80%9320_UEFA_Champions_League',
#  'https://en.wikipedia.org/wiki/2020%E2%80%9321_UEFA_Champions_League',
#  'https://en.wikipedia.org/wiki/2021%E2%80%9322_UEFA_Champions_League']

# %% [markdown]
# We will use BeautifulSoup to scrape data from those wikipedia pages. References for using BeautifulSoup are:
#
# https://stackoverflow.com/questions/3376803/beautifulsoup-find-th-with-text-price-then-get-price-from-next-th
# https://stackoverflow.com/questions/68612714/web-scraping-all-text-between-tabletable-i-need-table-in-python
# https://www.geeksforgeeks.org/how-to-find-a-html-tag-that-contains-certain-text-using-beautifulsoup/
# https://stackoverflow.com/questions/24748445/beautiful-soup-using-regex-to-find-tags
# https://www.geeksforgeeks.org/remove-all-style-scripts-and-html-tags-using-beautifulsoup/

# %%
import re
import pandas as pd
import requests
from bs4 import BeautifulSoup, NavigableString, Tag

# %% [markdown]
# We will assemble a data frame consisting of every group from all group stages. The columns name include the columns name from Wikipedia's tables, but we will also include team's association. For example, Milan belongs to the Italian Football Federation.

# %%
columns=["Association" , "Pos" , "Team" , "Pld" , "W" , "D" , "L" , "GF" , "GA" , "GD" , "Pts"] 

df_all_group_stages = pd.DataFrame(columns = columns)
df_all_group_stages
# Out:
# Empty DataFrame
# Columns: [Association, Pos, Team, Pld, W, D, L, GF, GA, GD, Pts]
# Index: []

# %% [markdown]
# From each url, for example https://en.wikipedia.org/wiki/1992–93_UEFA_Champions_League, we use BeautifulSoup to get the raw html for all groups.

# %%
def all_groups_in_a_season_redundant_html( year ):
    group_stage_redundant = BeautifulSoup(requests.get( url_array[year - 1992] ).content, "html.parser")
    
    all_groups_in_a_season_redundant = group_stage_redundant.find_all(lambda tag: tag.name == "th" and "Pld" in tag.text)
    
    all_groups_in_a_season_redundant = [x.parent.parent for x in all_groups_in_a_season_redundant]
    
    all_groups_in_a_season_redundant = list ( filter ( lambda x: len(x.find_all(lambda tag: tag.name =="abbr" and "Grp" in tag.text)) ==0 , all_groups_in_a_season_redundant ) )   
    
    return all_groups_in_a_season_redundant

# %% [markdown]
# We clean up the messy html to make data more accessible.

# %%
def a_group_in_a_season_cleaned_html(a_group_in_a_season_redundant_html):
    for abbr_title in a_group_in_a_season_redundant_html.find_all('abbr'):
        abbr_title.parent.decompose()

    for style_tag in a_group_in_a_season_redundant_html(['style']):
        style_tag.decompose()
    
    a_group_in_a_season_redundant_html.find_all(lambda tag:tag.name=="th" and "Team" in tag.text)[0].parent.decompose()
    
    for qualification_th in a_group_in_a_season_redundant_html.find_all(lambda tag: tag.name == "th" and "Qualification" in tag.text):
        qualification_th.decompose()
    
    for advance_to_td in a_group_in_a_season_redundant_html.find_all(lambda tag: tag.name == "td" and "Advance to" in tag.text):
        advance_to_td.decompose()
    
    for transfer_to_td in a_group_in_a_season_redundant_html.find_all(lambda tag: tag.name == "td" and "Transfer to" in tag.text):
        transfer_to_td.decompose()
        
    for head_to_head_td in a_group_in_a_season_redundant_html.find_all(lambda tag: tag.name == "td" and "—" in tag.text):
        head_to_head_td.decompose()
    
    for head_to_head_td in a_group_in_a_season_redundant_html.find_all('a', {'href': re.compile('group_stage#.*v_')}):
        head_to_head_td.parent.decompose()
    
    for empty_tds in a_group_in_a_season_redundant_html.find_all("td"):
        if empty_tds.text.strip() == "":
            empty_tds.decompose()
            
    for abbr in a_group_in_a_season_redundant_html.find_all('th', {'scope': "col"}):
        if len(abbr.find_all("span")) >0:
            abbr.decompose()

    for empty_ths in a_group_in_a_season_redundant_html.find_all("th"):
        if empty_ths.text.strip() == "":
            empty_ths.decompose()
    
    return a_group_in_a_season_redundant_html

# %% [markdown]
# We assemble the cleaned html for the table into a dataframe.

# %%
def a_group_html_to_dataframe(a_group_in_a_season_cleaned_html , which_group , which_year):
    all_data = []

    for tr in a_group_in_a_season_cleaned_html:
        if isinstance(tr, NavigableString):
            continue
        if isinstance(tr, Tag):
            association = tr.find("span").find("a")["title"]
            th = tr.find("th")
            th.name = "td"
            tds = [association] + [td.get_text(strip=True) for td in tr.select("td")]
            all_data.append(tds)

    df = pd.DataFrame(all_data , columns=columns)

    df["Season"] = [str(which_year) + "–" + str(which_year+1)[2:] ] * 4
    df["Group"] = [chr(ord('@')+ which_group + 1)] * 4

    df = df[["Season", "Group"] + columns]
    return df

# %% [markdown]
# For example, let's look at group A of season 1992-1993.

# %%
a_group_html_to_dataframe( a_group_in_a_season_cleaned_html( all_groups_in_a_season_redundant_html( 1992 )[0] ) , 0 , 1992 )
# Out:
#     Season Group                         Association Pos         Team Pld  W  \
# 0  1992–93     A          French Football Federation   1    Marseille   6  3
# 1  1992–93     A       Scottish Football Association   2      Rangers   6  2
# 2  1992–93     A  Royal Belgian Football Association   3  Club Brugge   6  2
# 3  1992–93     A              Russian Football Union   4  CSKA Moscow   6  0
#
#    D  L  GF  GA   GD Pts
# 0  3  0  14   4  +10   9
# 1  4  0   7   5   +2   8
# 2  1  3   5   8   −3   5
# 3  2  4   2  11   −9   2

# %% [markdown]
# Now we can put all data into one dataframe.

# %%
for year in range(1992,2022):
    all_groups_in_that_season_redundant_html = all_groups_in_a_season_redundant_html( year )
    total_group_numbers = len(all_groups_in_that_season_redundant_html)
    for which_group in range( total_group_numbers ):
        this_group_cleaned_html = a_group_in_a_season_cleaned_html( all_groups_in_that_season_redundant_html[which_group] )
        df_all_group_stages = pd.concat([ df_all_group_stages , a_group_html_to_dataframe(this_group_cleaned_html , which_group , year ) ] , ignore_index = True )
         
df_all_group_stages.tail(50)
# Out:
#                             Association Pos                    Team Pld  W  D  \
# 862    Royal Dutch Football Association   3                    Ajax   6  2  1
# 863         Danish Football Association   4             Midtjylland   6  0  2
# 864            The Football Association   1                 Chelsea   6  4  2
# 865   Royal Spanish Football Federation   2                 Sevilla   6  4  1
# 866              Russian Football Union   3               Krasnodar   6  1  2
# 867          French Football Federation   4                  Rennes   6  0  1
# 868         German Football Association   1       Borussia Dortmund   6  4  1
# 869         Italian Football Federation   2                   Lazio   6  2  4
# 870  Royal Belgian Football Association   3             Club Brugge   6  2  2
# 871              Russian Football Union   4  Zenit Saint Petersburg   6  0  1
# 872         Italian Football Federation   1                Juventus   6  5  0
# 873   Royal Spanish Football Federation   2               Barcelona   6  5  0
# 874   Ukrainian Association of Football   3             Dynamo Kyiv   6  1  1
# 875       Hungarian Football Federation   4             Ferencváros   6  0  1
# 876          French Football Federation   1     Paris Saint-Germain   6  4  0
# 877         German Football Association   2              RB Leipzig   6  4  0
# 878            The Football Association   3       Manchester United   6  3  0
# 879         Turkish Football Federation   4     İstanbul Başakşehir   6  1  0
# 880            The Football Association   1         Manchester City   6  4  0
# 881          French Football Federation   2     Paris Saint-Germain   6  3  2
# 882         German Football Association   3              RB Leipzig   6  2  1
# 883  Royal Belgian Football Association   4             Club Brugge   6  1  1
# 884            The Football Association   1               Liverpool   6  6  0
# 885   Royal Spanish Football Federation   2         Atlético Madrid   6  2  1
# 886      Portuguese Football Federation   3                   Porto   6  1  2
# 887         Italian Football Federation   4                   Milan   6  1  1
# 888    Royal Dutch Football Association   1                    Ajax   6  6  0
# 889      Portuguese Football Federation   2             Sporting CP   6  3  0
# 890         German Football Association   3       Borussia Dortmund   6  3  0
# 891         Turkish Football Federation   4                Beşiktaş   6  0  0
# 892   Royal Spanish Football Federation   1             Real Madrid   6  5  0
# 893         Italian Football Federation   2             Inter Milan   6  3  1
# 894        Moldovan Football Federation   3        Sheriff Tiraspol   6  2  1
# 895   Ukrainian Association of Football   4        Shakhtar Donetsk   6  0  2
# 896         German Football Association   1           Bayern Munich   6  6  0
# 897      Portuguese Football Federation   2                 Benfica   6  2  2
# 898   Royal Spanish Football Federation   3               Barcelona   6  2  1
# 899   Ukrainian Association of Football   4             Dynamo Kyiv   6  0  1
# 900            The Football Association   1       Manchester United   6  3  2
# 901   Royal Spanish Football Federation   2              Villarreal   6  3  1
# 902         Italian Football Federation   3                Atalanta   6  1  3
# 903          Swiss Football Association   4              Young Boys   6  1  2
# 904          French Football Federation   1                   Lille   6  3  2
# 905       Austrian Football Association   2       Red Bull Salzburg   6  3  1
# 906   Royal Spanish Football Federation   3                 Sevilla   6  1  3
# 907         German Football Association   4           VfL Wolfsburg   6  1  2
# 908         Italian Football Federation   1                Juventus   6  5  0
# 909            The Football Association   2                 Chelsea   6  4  1
# 910              Russian Football Union   3  Zenit Saint Petersburg   6  1  2
# 911        Swedish Football Association   4                Malmö FF   6  0  1
#
#      L  GF  GA   GD    Pts   Season Group
# 862  3   7   7    0      7  2020–21     D
# 863  4   4  13   −9      2  2020–21     D
# 864  0  14   2  +12     14  2020–21     E
# 865  1   9   8   +1     13  2020–21     E
# 866  3   6  11   −5      5  2020–21     E
# 867  5   3  11   −8      1  2020–21     E
# 868  1  12   5   +7     13  2020–21     F
# 869  0  11   7   +4     10  2020–21     F
# 870  2   8  10   −2      8  2020–21     F
# 871  5   4  13   −9      1  2020–21     F
# 872  1  14   4  +10  15[a]  2020–21     G
# 873  1  16   5  +11  15[a]  2020–21     G
# 874  4   4  13   −9      4  2020–21     G
# 875  5   5  17  −12      1  2020–21     G
# 876  2  13   6   +7  12[a]  2020–21     H
# 877  2  11  12   −1  12[a]  2020–21     H
# 878  3  15  10   +5      9  2020–21     H
# 879  5   7  18  −11      3  2020–21     H
# 880  2  18  10   +8     12  2021–22     A
# 881  1  13   8   +5     11  2021–22     A
# 882  3  15  14   +1      7  2021–22     A
# 883  4   6  20  −14      4  2021–22     A
# 884  0  17   6  +11     18  2021–22     B
# 885  3   7   8   −1      7  2021–22     B
# 886  3   4  11   −7      5  2021–22     B
# 887  4   6   9   −3      4  2021–22     B
# 888  0  20   5  +15     18  2021–22     C
# 889  3  14  12   +2   9[a]  2021–22     C
# 890  3  10  11   −1   9[a]  2021–22     C
# 891  6   3  19  −16      0  2021–22     C
# 892  1  14   3  +11     15  2021–22     D
# 893  2   8   5   +3     10  2021–22     D
# 894  3   7  11   −4      7  2021–22     D
# 895  4   2  12  −10      2  2021–22     D
# 896  0  22   3  +19     18  2021–22     E
# 897  2   7   9   −2      8  2021–22     E
# 898  3   2   9   −7      7  2021–22     E
# 899  5   1  11  −10      1  2021–22     E
# 900  1  11   8   +3     11  2021–22     F
# 901  2  12   9   +3     10  2021–22     F
# 902  2  12  13   −1      6  2021–22     F
# 903  3   7  12   −5      5  2021–22     F
# 904  1   7   4   +3     11  2021–22     G
# 905  2   8   6   +2     10  2021–22     G
# 906  2   5   5    0      6  2021–22     G
# 907  3   5  10   −5      5  2021–22     G
# 908  1  10   6   +4     15  2021–22     H
# 909  1  13   4   +9     13  2021–22     H
# 910  3  10  10    0      5  2021–22     H
# 911  5   1  14  −13      1  2021–22     H

# %% [markdown]
# We notice that there are rows with footer notes. We will delete those footers. We also convert strings into ints.

# %%
pd.concat([ df_all_group_stages[df_all_group_stages["Pts"].str.contains('\[a')] ,
        df_all_group_stages[df_all_group_stages["Pts"].str.contains('\[b')],
        df_all_group_stages[df_all_group_stages["Pts"].str.contains('\[c')] ] , ignore_index = True)
# Out:
#                           Association Pos                      Team Pld  W  D  \
# 0         Italian Football Federation   2                     Milan   6  3  1
# 1   Ukrainian Association of Football   2          Shakhtar Donetsk   6  3  1
# 2            The Football Association   3                   Chelsea   6  3  1
# 3                              France   1       Paris Saint-Germain   6  5  0
# 4                             Germany   2             Bayern Munich   6  5  0
# 5                               Italy   1                      Roma   6  3  2
# 6                             England   2                   Chelsea   6  3  2
# 7                             Germany   3         Borussia Dortmund   6  0  2
# 8                              Cyprus   4                     APOEL   6  0  2
# 9                             Germany   1         Borussia Dortmund   6  4  1
# 10                              Spain   2           Atlético Madrid   6  4  1
# 11                            England   2         Tottenham Hotspur   6  2  2
# 12                              Italy   3               Inter Milan   6  2  2
# 13                            England   2                 Liverpool   6  3  0
# 14                              Italy   3                    Napoli   6  2  3
# 15                     Czech Republic   3            Viktoria Plzeň   6  2  1
# 16                             Russia   4               CSKA Moscow   6  2  1
# 17     Portuguese Football Federation   3                   Benfica   6  2  1
# 18             Russian Football Union   4    Zenit Saint Petersburg   6  2  1
# 19  Royal Spanish Football Federation   1                  Valencia   6  3  2
# 20           The Football Association   2                   Chelsea   6  3  2
# 21        German Football Association   2  Borussia Mönchengladbach   6  2  2
# 22  Ukrainian Association of Football   3          Shakhtar Donetsk   6  2  2
# 23       Hellenic Football Federation   3                Olympiacos   6  1  0
# 24         French Football Federation   4                 Marseille   6  1  0
# 25        Italian Football Federation   1                  Juventus   6  5  0
# 26  Royal Spanish Football Federation   2                 Barcelona   6  5  0
# 27         French Football Federation   1       Paris Saint-Germain   6  4  0
# 28        German Football Association   2                RB Leipzig   6  4  0
# 29     Portuguese Football Federation   2               Sporting CP   6  3  0
# 30        German Football Association   3         Borussia Dortmund   6  3  0
# 31                           Scotland   3                    Celtic   6  1  0
# 32                            Belgium   4                Anderlecht   6  1  0
#
#     L  GF  GA   GD    Pts   Season Group
# 0   2   6   5   +1   8[a]  1994–95     D
# 1   2  12   8   +4  10[a]  2012–13     E
# 2   2  16  10   +6  10[a]  2012–13     E
# 3   1  25   4  +21  15[a]  2017–18     B
# 4   1  13   6   +7  15[a]  2017–18     B
# 5   1   9   6   +3  11[a]  2017–18     C
# 6   1  16   8   +8  11[a]  2017–18     C
# 7   4   7  13   −6   2[a]  2017–18     H
# 8   4   2  17  −15   2[a]  2017–18     H
# 9   1  10   2   +8  13[a]  2018–19     A
# 10  1   9   6   +3  13[a]  2018–19     A
# 11  2   9  10   −1   8[a]  2018–19     B
# 12  2   6   7   −1   8[a]  2018–19     B
# 13  3   9   7   +2   9[a]  2018–19     C
# 14  1   7   5   +2   9[a]  2018–19     C
# 15  3   7  16   −9   7[a]  2018–19     G
# 16  3   8   9   −1   7[a]  2018–19     G
# 17  3  10  11   −1   7[a]  2019–20     G
# 18  3   7   9   −2   7[a]  2019–20     G
# 19  1   9   7   +2  11[a]  2019–20     H
# 20  1  11   9   +2  11[a]  2019–20     H
# 21  2  16   9   +7   8[a]  2020–21     B
# 22  2   5  12   −7   8[a]  2020–21     B
# 23  5   2  10   −8   3[a]  2020–21     C
# 24  5   2  13  −11   3[a]  2020–21     C
# 25  1  14   4  +10  15[a]  2020–21     G
# 26  1  16   5  +11  15[a]  2020–21     G
# 27  2  13   6   +7  12[a]  2020–21     H
# 28  2  11  12   −1  12[a]  2020–21     H
# 29  3  14  12   +2   9[a]  2021–22     C
# 30  3  10  11   −1   9[a]  2021–22     C
# 31  5   5  18  −13   3[b]  2017–18     B
# 32  5   2  17  −15   3[b]  2017–18     B

# %%
for column in columns:
    df_all_group_stages[column] = df_all_group_stages[column].transform(lambda x : x[0 : x.find("[a")] if x.find("[a") >0 else x )
    df_all_group_stages[column] = df_all_group_stages[column].transform(lambda x : x[0 : x.find("[b")] if x.find("[b") >0 else x )

for column in ["Pld" , "W" , "D" , "L" , "GF" , "GA" , "GD" , "Pts"]:
    if column != "Pts" and column != "GD":
        df_all_group_stages[column] = df_all_group_stages[column].astype(int)
    else:
        df_all_group_stages[column] = df_all_group_stages[column].transform(lambda x : '-' + x[1:] if x.find("−") == 0 else x )
        df_all_group_stages[column] = df_all_group_stages[column].astype(int)
        
df_all_group_stages.tail(50)
# Out:
#                             Association Pos                    Team  Pld  W  \
# 862    Royal Dutch Football Association   3                    Ajax    6  2
# 863         Danish Football Association   4             Midtjylland    6  0
# 864            The Football Association   1                 Chelsea    6  4
# 865   Royal Spanish Football Federation   2                 Sevilla    6  4
# 866              Russian Football Union   3               Krasnodar    6  1
# 867          French Football Federation   4                  Rennes    6  0
# 868         German Football Association   1       Borussia Dortmund    6  4
# 869         Italian Football Federation   2                   Lazio    6  2
# 870  Royal Belgian Football Association   3             Club Brugge    6  2
# 871              Russian Football Union   4  Zenit Saint Petersburg    6  0
# 872         Italian Football Federation   1                Juventus    6  5
# 873   Royal Spanish Football Federation   2               Barcelona    6  5
# 874   Ukrainian Association of Football   3             Dynamo Kyiv    6  1
# 875       Hungarian Football Federation   4             Ferencváros    6  0
# 876          French Football Federation   1     Paris Saint-Germain    6  4
# 877         German Football Association   2              RB Leipzig    6  4
# 878            The Football Association   3       Manchester United    6  3
# 879         Turkish Football Federation   4     İstanbul Başakşehir    6  1
# 880            The Football Association   1         Manchester City    6  4
# 881          French Football Federation   2     Paris Saint-Germain    6  3
# 882         German Football Association   3              RB Leipzig    6  2
# 883  Royal Belgian Football Association   4             Club Brugge    6  1
# 884            The Football Association   1               Liverpool    6  6
# 885   Royal Spanish Football Federation   2         Atlético Madrid    6  2
# 886      Portuguese Football Federation   3                   Porto    6  1
# 887         Italian Football Federation   4                   Milan    6  1
# 888    Royal Dutch Football Association   1                    Ajax    6  6
# 889      Portuguese Football Federation   2             Sporting CP    6  3
# 890         German Football Association   3       Borussia Dortmund    6  3
# 891         Turkish Football Federation   4                Beşiktaş    6  0
# 892   Royal Spanish Football Federation   1             Real Madrid    6  5
# 893         Italian Football Federation   2             Inter Milan    6  3
# 894        Moldovan Football Federation   3        Sheriff Tiraspol    6  2
# 895   Ukrainian Association of Football   4        Shakhtar Donetsk    6  0
# 896         German Football Association   1           Bayern Munich    6  6
# 897      Portuguese Football Federation   2                 Benfica    6  2
# 898   Royal Spanish Football Federation   3               Barcelona    6  2
# 899   Ukrainian Association of Football   4             Dynamo Kyiv    6  0
# 900            The Football Association   1       Manchester United    6  3
# 901   Royal Spanish Football Federation   2              Villarreal    6  3
# 902         Italian Football Federation   3                Atalanta    6  1
# 903          Swiss Football Association   4              Young Boys    6  1
# 904          French Football Federation   1                   Lille    6  3
# 905       Austrian Football Association   2       Red Bull Salzburg    6  3
# 906   Royal Spanish Football Federation   3                 Sevilla    6  1
# 907         German Football Association   4           VfL Wolfsburg    6  1
# 908         Italian Football Federation   1                Juventus    6  5
# 909            The Football Association   2                 Chelsea    6  4
# 910              Russian Football Union   3  Zenit Saint Petersburg    6  1
# 911        Swedish Football Association   4                Malmö FF    6  0
#
#      D  L  GF  GA  GD  Pts   Season Group
# 862  1  3   7   7   0    7  2020–21     D
# 863  2  4   4  13  -9    2  2020–21     D
# 864  2  0  14   2  12   14  2020–21     E
# 865  1  1   9   8   1   13  2020–21     E
# 866  2  3   6  11  -5    5  2020–21     E
# 867  1  5   3  11  -8    1  2020–21     E
# 868  1  1  12   5   7   13  2020–21     F
# 869  4  0  11   7   4   10  2020–21     F
# 870  2  2   8  10  -2    8  2020–21     F
# 871  1  5   4  13  -9    1  2020–21     F
# 872  0  1  14   4  10   15  2020–21     G
# 873  0  1  16   5  11   15  2020–21     G
# 874  1  4   4  13  -9    4  2020–21     G
# 875  1  5   5  17 -12    1  2020–21     G
# 876  0  2  13   6   7   12  2020–21     H
# 877  0  2  11  12  -1   12  2020–21     H
# 878  0  3  15  10   5    9  2020–21     H
# 879  0  5   7  18 -11    3  2020–21     H
# 880  0  2  18  10   8   12  2021–22     A
# 881  2  1  13   8   5   11  2021–22     A
# 882  1  3  15  14   1    7  2021–22     A
# 883  1  4   6  20 -14    4  2021–22     A
# 884  0  0  17   6  11   18  2021–22     B
# 885  1  3   7   8  -1    7  2021–22     B
# 886  2  3   4  11  -7    5  2021–22     B
# 887  1  4   6   9  -3    4  2021–22     B
# 888  0  0  20   5  15   18  2021–22     C
# 889  0  3  14  12   2    9  2021–22     C
# 890  0  3  10  11  -1    9  2021–22     C
# 891  0  6   3  19 -16    0  2021–22     C
# 892  0  1  14   3  11   15  2021–22     D
# 893  1  2   8   5   3   10  2021–22     D
# 894  1  3   7  11  -4    7  2021–22     D
# 895  2  4   2  12 -10    2  2021–22     D
# 896  0  0  22   3  19   18  2021–22     E
# 897  2  2   7   9  -2    8  2021–22     E
# 898  1  3   2   9  -7    7  2021–22     E
# 899  1  5   1  11 -10    1  2021–22     E
# 900  2  1  11   8   3   11  2021–22     F
# 901  1  2  12   9   3   10  2021–22     F
# 902  3  2  12  13  -1    6  2021–22     F
# 903  2  3   7  12  -5    5  2021–22     F
# 904  2  1   7   4   3   11  2021–22     G
# 905  1  2   8   6   2   10  2021–22     G
# 906  3  2   5   5   0    6  2021–22     G
# 907  2  3   5  10  -5    5  2021–22     G
# 908  0  1  10   6   4   15  2021–22     H
# 909  1  1  13   4   9   13  2021–22     H
# 910  2  3  10  10   0    5  2021–22     H
# 911  1  5   1  14 -13    1  2021–22     H

# %% [markdown]
# Another issue is that some countries' football association's name is incomplete. There is another issue that Football Association of Serbia and Montenegro splits into Football Association of Serbia.

# %%
sorted(df_all_group_stages["Association"].unique())
# Out:
# ['Austrian Football Association',
#  'Azerbaijan',
#  'Belarus',
#  'Belgium',
#  'Bulgaria',
#  'Bulgarian Football Union',
#  'Croatia',
#  'Croatian Football Federation',
#  'Cyprus',
#  'Cyprus Football Association',
#  'Czech Republic',
#  'Danish Football Association',
#  'Denmark',
#  'England',
#  'Football Association of Finland',
#  'Football Association of Serbia',
#  'Football Association of Serbia and Montenegro',
#  'Football Association of Slovenia',
#  'Football Association of the Czech Republic',
#  'Football Federation of Belarus',
#  'France',
#  'French Football Federation',
#  'German Football Association',
#  'Germany',
#  'Greece',
#  'Hellenic Football Federation',
#  'Hungarian Football Federation',
#  'Israel',
#  'Israel Football Association',
#  'Italian Football Federation',
#  'Italy',
#  'Kazakhstan',
#  'Moldovan Football Federation',
#  'Netherlands',
#  'Norwegian Football Federation',
#  'Poland',
#  'Polish Football Association',
#  'Portugal',
#  'Portuguese Football Federation',
#  'Romanian Football Federation',
#  'Royal Belgian Football Association',
#  'Royal Dutch Football Association',
#  'Royal Spanish Football Federation',
#  'Russia',
#  'Russian Football Union',
#  'Scotland',
#  'Scottish Football Association',
#  'Serbia',
#  'Slovak Football Association',
#  'Slovenia',
#  'Spain',
#  'Sweden',
#  'Swedish Football Association',
#  'Swiss Football Association',
#  'Switzerland',
#  'The Football Association',
#  'Turkey',
#  'Turkish Football Federation',
#  'Ukraine',
#  'Ukrainian Association of Football']

# %%
pd.concat ( [ df_all_group_stages[ df_all_group_stages["Association"]=='Serbia'] ,
df_all_group_stages[ df_all_group_stages["Association"]=='Football Association of Serbia'] ,
df_all_group_stages[ df_all_group_stages["Association"]=='Football Association of Serbia and Montenegro'] ] , ignore_index = True )
# Out:
#                                      Association Pos               Team  Pld  \
# 0                                         Serbia   4  Red Star Belgrade    6
# 1                 Football Association of Serbia   4           Partizan    6
# 2                 Football Association of Serbia   4  Red Star Belgrade    6
# 3  Football Association of Serbia and Montenegro   4           Partizan    6
#
#    W  D  L  GF  GA  GD  Pts   Season Group
# 0  1  1  4   5  17 -12    4  2018–19     C
# 1  0  0  6   2  13 -11    0  2010–11     H
# 2  1  0  5   3  20 -17    3  2019–20     B
# 3  0  3  3   3   8  -5    3  2003–04     F

# %%
association_name_replacement = {
    'Azerbaijan': 'Association of Football Federations of Azerbaijan',
    'Belarus': 'Football Federation of Belarus',
    'Belgium': 'Royal Belgian Football Association',
    'Bulgaria': 'Bulgarian Football Union',
    'Croatia': 'Croatian Football Federation',
    'Cyprus': 'Cyprus Football Association',
    'Czech Republic': 'Football Association of the Czech Republic',
    'Denmark': 'Danish Football Association',
    'England': 'The Football Association',
    'France': 'French Football Federation',
    'Football Association of Serbia and Montenegro': 'Football Association of Serbia',
    'Germany': 'German Football Association',
    'Greece': 'Hellenic Football Federation',
    'Israel': 'Israel Football Association',
    'Italy': 'Italian Football Federation',
    'Kazakhstan': 'Kazakhstan Football Federation',
    'Netherlands': 'Royal Dutch Football Association',
    'Poland': 'Polish Football Association',
    'Portugal': 'Portuguese Football Federation',
    'Russia': 'Russian Football Union',
    'Scotland': 'Scottish Football Association',
    'Serbia': 'Football Association of Serbia',
    'Slovenia': 'Football Association of Slovenia',
    'Spain': 'Royal Spanish Football Federation',
    'Sweden':'Swedish Football Association',
    'Switzerland':'Swiss Football Association',
    'Turkey': 'Turkish Football Federation',
    'Ukraine': 'Ukrainian Association of Football'
}

df_all_group_stages["Association"] = df_all_group_stages["Association"].transform(lambda x : association_name_replacement[x] if x in association_name_replacement.keys() else x )

sorted(df_all_group_stages["Association"].unique())
# Out:
# ['Association of Football Federations of Azerbaijan',
#  'Austrian Football Association',
#  'Bulgarian Football Union',
#  'Croatian Football Federation',
#  'Cyprus Football Association',
#  'Danish Football Association',
#  'Football Association of Finland',
#  'Football Association of Serbia',
#  'Football Association of Slovenia',
#  'Football Association of the Czech Republic',
#  'Football Federation of Belarus',
#  'French Football Federation',
#  'German Football Association',
#  'Hellenic Football Federation',
#  'Hungarian Football Federation',
#  'Israel Football Association',
#  'Italian Football Federation',
#  'Kazakhstan Football Federation',
#  'Moldovan Football Federation',
#  'Norwegian Football Federation',
#  'Polish Football Association',
#  'Portuguese Football Federation',
#  'Romanian Football Federation',
#  'Royal Belgian Football Association',
#  'Royal Dutch Football Association',
#  'Royal Spanish Football Federation',
#  'Russian Football Union',
#  'Scottish Football Association',
#  'Slovak Football Association',
#  'Swedish Football Association',
#  'Swiss Football Association',
#  'The Football Association',
#  'Turkish Football Federation',
#  'Ukrainian Association of Football']

# %% [markdown]
# Another issue is that team names also have duplicates, for example PSV and PSV Eindhoven, Inter Milan and Internazionale.

# %%
sorted( df_all_group_stages["Team"].unique() )
# Out:
# ['1899 Hoffenheim',
#  'AEK Athens',
#  'AIK',
#  'APOEL',
#  'AZ',
#  'AaB',
#  'Aalborg BK',
#  'Ajax',
#  'Anderlecht',
#  'Anorthosis',
#  'Arsenal',
#  'Artmedia',
#  'Astana',
#  'Atalanta',
#  'Athletic Bilbao',
#  'Atlético Madrid',
#  'Austria Wien',
#  'Auxerre',
#  'BATE Borisov',
#  'Barcelona',
#  'Basel',
#  'Bayer Leverkusen',
#  'Bayern Munich',
#  'Benfica',
#  'Beşiktaş',
#  'Blackburn Rovers',
#  'Boavista',
#  'Bordeaux',
#  'Borussia Dortmund',
#  'Borussia Mönchengladbach',
#  'Braga',
#  'Brøndby',
#  'Bursaspor',
#  'CFR Cluj',
#  'CSKA Moscow',
#  'Casino Salzburg',
#  'Celta Vigo',
#  'Celtic',
#  'Chelsea',
#  'Club Brugge',
#  'Copenhagen',
#  'Croatia Zagreb',
#  'Debrecen',
#  'Deportivo La Coruña',
#  'Dinamo Zagreb',
#  'Dynamo Kyiv',
#  'Fenerbahçe',
#  'Ferencváros',
#  'Feyenoord',
#  'Fiorentina',
#  'Galatasaray',
#  'Genk',
#  'Gent',
#  'Grasshopper',
#  'HJK',
#  'Hajduk Split',
#  'Hamburg',
#  'Hapoel Tel Aviv',
#  'Heerenveen',
#  'Helsingborg',
#  'Hertha BSC',
#  'IFK Göteborg',
#  'Inter Milan',
#  'Internazionale',
#  'Juventus',
#  'Kaiserslautern',
#  'Košice',
#  'Krasnodar',
#  'Lazio',
#  'Leeds United',
#  'Legia Warsaw',
#  'Leicester City',
#  'Lens',
#  'Levski Sofia',
#  'Lierse',
#  'Lille',
#  'Liverpool',
#  'Lokomotiv Moscow',
#  'Ludogorets Razgrad',
#  'Lyon',
#  'Maccabi Haifa',
#  'Maccabi Tel Aviv',
#  'Mallorca',
#  'Malmö FF',
#  'Manchester City',
#  'Manchester United',
#  'Maribor',
#  'Marseille',
#  'Midtjylland',
#  'Milan',
#  'Molde',
#  'Monaco',
#  'Montpellier',
#  'Málaga',
#  'Nantes',
#  'Napoli',
#  'Newcastle United',
#  'Nordsjælland',
#  'Olympiacos',
#  'Oțelul Galați',
#  'PSV',
#  'PSV Eindhoven',
#  'Panathinaikos',
#  'Paris Saint-Germain',
#  'Parma',
#  'Partizan',
#  'Porto',
#  'Qarabağ',
#  'RB Leipzig',
#  'Rangers',
#  'Rapid Wien',
#  'Real Betis',
#  'Real Madrid',
#  'Real Sociedad',
#  'Red Bull Salzburg',
#  'Red Star Belgrade',
#  'Rennes',
#  'Roma',
#  'Rosenborg',
#  'Rostov',
#  'Rubin Kazan',
#  'Schalke 04',
#  'Sevilla',
#  'Shakhtar Donetsk',
#  'Sheriff Tiraspol',
#  'Slavia Prague',
#  'Sparta Prague',
#  'Spartak Moscow',
#  'Sporting CP',
#  'Standard Liège',
#  'Steaua București',
#  'Sturm Graz',
#  'Stuttgart',
#  'Thun',
#  'Tottenham Hotspur',
#  'Trabzonspor',
#  'Twente',
#  'Udinese',
#  'Unirea Urziceni',
#  'Valencia',
#  'VfL Wolfsburg',
#  'Viktoria Plzeň',
#  'Villarreal',
#  'Werder Bremen',
#  'Widzew Łódź',
#  'Willem II',
#  'Wolfsburg',
#  'Young Boys',
#  'Zenit Saint Petersburg',
#  'Zürich',
#  'İstanbul Başakşehir',
#  'Žilina']

# %%
team_name_replacement = {
    'PSV': 'PSV Eindhoven',
    'Internazionale': 'Inter Milan'
}

df_all_group_stages["Team"] = df_all_group_stages["Team"].transform(lambda x : team_name_replacement[x] if x in team_name_replacement.keys() else x )

sorted(df_all_group_stages["Team"].unique())
# Out:
# ['1899 Hoffenheim',
#  'AEK Athens',
#  'AIK',
#  'APOEL',
#  'AZ',
#  'AaB',
#  'Aalborg BK',
#  'Ajax',
#  'Anderlecht',
#  'Anorthosis',
#  'Arsenal',
#  'Artmedia',
#  'Astana',
#  'Atalanta',
#  'Athletic Bilbao',
#  'Atlético Madrid',
#  'Austria Wien',
#  'Auxerre',
#  'BATE Borisov',
#  'Barcelona',
#  'Basel',
#  'Bayer Leverkusen',
#  'Bayern Munich',
#  'Benfica',
#  'Beşiktaş',
#  'Blackburn Rovers',
#  'Boavista',
#  'Bordeaux',
#  'Borussia Dortmund',
#  'Borussia Mönchengladbach',
#  'Braga',
#  'Brøndby',
#  'Bursaspor',
#  'CFR Cluj',
#  'CSKA Moscow',
#  'Casino Salzburg',
#  'Celta Vigo',
#  'Celtic',
#  'Chelsea',
#  'Club Brugge',
#  'Copenhagen',
#  'Croatia Zagreb',
#  'Debrecen',
#  'Deportivo La Coruña',
#  'Dinamo Zagreb',
#  'Dynamo Kyiv',
#  'Fenerbahçe',
#  'Ferencváros',
#  'Feyenoord',
#  'Fiorentina',
#  'Galatasaray',
#  'Genk',
#  'Gent',
#  'Grasshopper',
#  'HJK',
#  'Hajduk Split',
#  'Hamburg',
#  'Hapoel Tel Aviv',
#  'Heerenveen',
#  'Helsingborg',
#  'Hertha BSC',
#  'IFK Göteborg',
#  'Inter Milan',
#  'Juventus',
#  'Kaiserslautern',
#  'Košice',
#  'Krasnodar',
#  'Lazio',
#  'Leeds United',
#  'Legia Warsaw',
#  'Leicester City',
#  'Lens',
#  'Levski Sofia',
#  'Lierse',
#  'Lille',
#  'Liverpool',
#  'Lokomotiv Moscow',
#  'Ludogorets Razgrad',
#  'Lyon',
#  'Maccabi Haifa',
#  'Maccabi Tel Aviv',
#  'Mallorca',
#  'Malmö FF',
#  'Manchester City',
#  'Manchester United',
#  'Maribor',
#  'Marseille',
#  'Midtjylland',
#  'Milan',
#  'Molde',
#  'Monaco',
#  'Montpellier',
#  'Málaga',
#  'Nantes',
#  'Napoli',
#  'Newcastle United',
#  'Nordsjælland',
#  'Olympiacos',
#  'Oțelul Galați',
#  'PSV Eindhoven',
#  'Panathinaikos',
#  'Paris Saint-Germain',
#  'Parma',
#  'Partizan',
#  'Porto',
#  'Qarabağ',
#  'RB Leipzig',
#  'Rangers',
#  'Rapid Wien',
#  'Real Betis',
#  'Real Madrid',
#  'Real Sociedad',
#  'Red Bull Salzburg',
#  'Red Star Belgrade',
#  'Rennes',
#  'Roma',
#  'Rosenborg',
#  'Rostov',
#  'Rubin Kazan',
#  'Schalke 04',
#  'Sevilla',
#  'Shakhtar Donetsk',
#  'Sheriff Tiraspol',
#  'Slavia Prague',
#  'Sparta Prague',
#  'Spartak Moscow',
#  'Sporting CP',
#  'Standard Liège',
#  'Steaua București',
#  'Sturm Graz',
#  'Stuttgart',
#  'Thun',
#  'Tottenham Hotspur',
#  'Trabzonspor',
#  'Twente',
#  'Udinese',
#  'Unirea Urziceni',
#  'Valencia',
#  'VfL Wolfsburg',
#  'Viktoria Plzeň',
#  'Villarreal',
#  'Werder Bremen',
#  'Widzew Łódź',
#  'Willem II',
#  'Wolfsburg',
#  'Young Boys',
#  'Zenit Saint Petersburg',
#  'Zürich',
#  'İstanbul Başakşehir',
#  'Žilina']

# %% [markdown]
# The data cleaning is now complete. We aggregate our data into dictionaries and visualize them.

# %%
individual_team_data = {
    "W": {},
    "D": {},
    "L": {},
    "GF": {},
    "GA": {},
    "GD": {},
    "Pts": {}
}

individual_association_data = {
    "W": {},
    "D": {},
    "L": {},
    "GF": {},
    "GA": {},
    "GD": {},
    "Pts": {}
}

for team in df_all_group_stages["Team"].unique():
    for column in ["W", "D", "L" , "GF" , "GA" , "GD" , "Pts"]:  
        individual_team_data[column][team] = df_all_group_stages[df_all_group_stages["Team"]== team][column].sum()

for association in df_all_group_stages["Association"].unique():
    for column in ["W", "D", "L" , "GF" , "GA" , "GD" , "Pts"]:  
        individual_association_data[column][association] = df_all_group_stages[df_all_group_stages["Association"]== association][column].sum()

# %%
individual_team_data_df = pd.DataFrame.from_dict(individual_team_data)

individual_team_data_df
# Out:
#                       W   D   L   GF   GA  GD  Pts
# Marseille            21  10  35   82   94 -12   70
# Rangers              12  21  27   60   91 -31   55
# Club Brugge          11  15  28   47   89 -42   46
# CSKA Moscow          17  16  39   77  122 -45   67
# Milan                54  35  31  170  113  57  189
# ...                  ..  ..  ..  ...  ...  ..  ...
# Midtjylland           0   2   4    4   13  -9    2
# Krasnodar             1   2   3    6   11  -5    5
# Rennes                0   1   5    3   11  -8    1
# İstanbul Başakşehir   1   0   5    7   18 -11    3
# Sheriff Tiraspol      2   1   3    7   11  -4    7
#
# [150 rows x 7 columns]

# %%
individual_association_data_df = pd.DataFrame.from_dict(individual_association_data)

individual_association_data_df
# Out:
#                                                      W    D    L    GF   GA  \
# French Football Federation                         182  102  160   667  552
# Scottish Football Association                       30   30   60   119  197
# Royal Belgian Football Association                  28   47   93   139  312
# Russian Football Union                              67   65  138   289  437
# Italian Football Federation                        263  163  150   873  638
# Swedish Football Association                        13    5   36    44  117
# Portuguese Football Federation                     133   75  134   435  443
# Royal Dutch Football Association                    86   68  110   312  366
# Royal Spanish Football Federation                  368  167  143  1232  697
# Turkish Football Federation                         49   47  114   193  376
# German Football Association                        264  125  169   956  716
# The Football Association                           347  152  143  1177  636
# Ukrainian Association of Football                   62   46  102   260  335
# Croatian Football Federation                         7    9   32    34   99
# Romanian Football Federation                        11   19   42    61  116
# Austrian Football Association                       15   12   39    68  132
# Hellenic Football Federation                        61   48  107   229  350
# Danish Football Association                         11   13   30    49  107
# Polish Football Association                          4    3   11    20   42
# Norwegian Football Federation                       20   17   41   100  140
# Hungarian Football Federation                        1    3   14    19   55
# Swiss Football Association                          24   19   47    95  155
# Football Association of the Czech Republic          18   21   45    82  152
# Slovak Football Association                          1    3   14    10   41
# Football Association of Finland                      1    2    3     8   12
# Football Association of Slovenia                     1    7   10     9   41
# Israel Football Association                          4    4   22    24   58
# Football Association of Serbia                       2    4   18    13   58
# Bulgarian Football Union                             1    4   13    12   46
# Cyprus Football Association                          3   12   15    21   50
# Football Federation of Belarus                       4    7   19    21   73
# Kazakhstan Football Federation                       0    4    2     5   11
# Association of Football Federations of Azerbaijan    0    2    4     2   14
# Moldovan Football Federation                         2    1    3     7   11
#
#                                                     GD   Pts
# French Football Federation                         115   645
# Scottish Football Association                      -78   118
# Royal Belgian Football Association                -173   129
# Russian Football Union                            -148   266
# Italian Football Federation                        235   944
# Swedish Football Association                       -73    41
# Portuguese Football Federation                      -8   472
# Royal Dutch Football Association                   -54   326
# Royal Spanish Football Federation                  535  1271
# Turkish Football Federation                       -183   194
# German Football Association                        240   917
# The Football Association                           541  1193
# Ukrainian Association of Football                  -75   232
# Croatian Football Federation                       -65    30
# Romanian Football Federation                       -55    52
# Austrian Football Association                      -64    57
# Hellenic Football Federation                      -121   231
# Danish Football Association                        -58    46
# Polish Football Association                        -22    15
# Norwegian Football Federation                      -40    77
# Hungarian Football Federation                      -36     6
# Swiss Football Association                         -60    91
# Football Association of the Czech Republic         -70    75
# Slovak Football Association                        -31     6
# Football Association of Finland                     -4     5
# Football Association of Slovenia                   -32    10
# Israel Football Association                        -34    16
# Football Association of Serbia                     -45    10
# Bulgarian Football Union                           -34     7
# Cyprus Football Association                        -29    21
# Football Federation of Belarus                     -52    19
# Kazakhstan Football Federation                      -6     4
# Association of Football Federations of Azerbaijan  -12     2
# Moldovan Football Federation                        -4     7

# %% [markdown]
# Let's look at a bar chart representing the top 10 associations by total wins.

# %%
import matplotlib.pyplot as plt

df_bar_chart = individual_association_data_df.sort_values("W",ascending = False)

df_bar_chart
# Out:
#                                                      W    D    L    GF   GA  \
# Royal Spanish Football Federation                  368  167  143  1232  697
# The Football Association                           347  152  143  1177  636
# German Football Association                        264  125  169   956  716
# Italian Football Federation                        263  163  150   873  638
# French Football Federation                         182  102  160   667  552
# Portuguese Football Federation                     133   75  134   435  443
# Royal Dutch Football Association                    86   68  110   312  366
# Russian Football Union                              67   65  138   289  437
# Ukrainian Association of Football                   62   46  102   260  335
# Hellenic Football Federation                        61   48  107   229  350
# Turkish Football Federation                         49   47  114   193  376
# Scottish Football Association                       30   30   60   119  197
# Royal Belgian Football Association                  28   47   93   139  312
# Swiss Football Association                          24   19   47    95  155
# Norwegian Football Federation                       20   17   41   100  140
# Football Association of the Czech Republic          18   21   45    82  152
# Austrian Football Association                       15   12   39    68  132
# Swedish Football Association                        13    5   36    44  117
# Danish Football Association                         11   13   30    49  107
# Romanian Football Federation                        11   19   42    61  116
# Croatian Football Federation                         7    9   32    34   99
# Polish Football Association                          4    3   11    20   42
# Israel Football Association                          4    4   22    24   58
# Football Federation of Belarus                       4    7   19    21   73
# Cyprus Football Association                          3   12   15    21   50
# Football Association of Serbia                       2    4   18    13   58
# Moldovan Football Federation                         2    1    3     7   11
# Hungarian Football Federation                        1    3   14    19   55
# Slovak Football Association                          1    3   14    10   41
# Football Association of Finland                      1    2    3     8   12
# Football Association of Slovenia                     1    7   10     9   41
# Bulgarian Football Union                             1    4   13    12   46
# Kazakhstan Football Federation                       0    4    2     5   11
# Association of Football Federations of Azerbaijan    0    2    4     2   14
#
#                                                     GD   Pts
# Royal Spanish Football Federation                  535  1271
# The Football Association                           541  1193
# German Football Association                        240   917
# Italian Football Federation                        235   944
# French Football Federation                         115   645
# Portuguese Football Federation                      -8   472
# Royal Dutch Football Association                   -54   326
# Russian Football Union                            -148   266
# Ukrainian Association of Football                  -75   232
# Hellenic Football Federation                      -121   231
# Turkish Football Federation                       -183   194
# Scottish Football Association                      -78   118
# Royal Belgian Football Association                -173   129
# Swiss Football Association                         -60    91
# Norwegian Football Federation                      -40    77
# Football Association of the Czech Republic         -70    75
# Austrian Football Association                      -64    57
# Swedish Football Association                       -73    41
# Danish Football Association                        -58    46
# Romanian Football Federation                       -55    52
# Croatian Football Federation                       -65    30
# Polish Football Association                        -22    15
# Israel Football Association                        -34    16
# Football Federation of Belarus                     -52    19
# Cyprus Football Association                        -29    21
# Football Association of Serbia                     -45    10
# Moldovan Football Federation                        -4     7
# Hungarian Football Federation                      -36     6
# Slovak Football Association                        -31     6
# Football Association of Finland                     -4     5
# Football Association of Slovenia                   -32    10
# Bulgarian Football Union                           -34     7
# Kazakhstan Football Federation                      -6     4
# Association of Football Federations of Azerbaijan  -12     2

# %%
bars = plt.barh( df_bar_chart.index.tolist() [9::-1] , df_bar_chart["W"].values[9::-1], align='center', linewidth=0, color='lightslategrey'  )

plt.xticks([])

for spine in plt.gca().spines.values():
    spine.set_visible(False)

for bar in bars:
    width = bar.get_width()
    plt.gca().text( bar.get_width() - 20, bar.get_y() + bar.get_height() / 2 - 0.15 , str(int(width)),
                   ha='center', color='w', fontsize=11)
